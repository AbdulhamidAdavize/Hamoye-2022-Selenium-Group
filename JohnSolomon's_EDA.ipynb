# %%
# Modules/Libraries for Exploratory Data Analysis (EDA)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing Our Foreign Exchange Dataset
dataset = pd.read_csv('dataset/Foreign_Exchange_Rates.csv')
dataset
# Out:
#       Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0              0  2000-01-03                            1.5172
# 1              1  2000-01-04                            1.5239
# 2              2  2000-01-05                            1.5267
# 3              3  2000-01-06                            1.5291
# 4              4  2000-01-07                            1.5272
# ...          ...         ...                               ...
# 5212        5212  2019-12-25                                ND
# 5213        5213  2019-12-26                            1.4411
# 5214        5214  2019-12-27                            1.4331
# 5215        5215  2019-12-30                            1.4278
# 5216        5216  2019-12-31                            1.4225
#
#      EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                  0.9847                              1.9033
# 1                    0.97                              1.9238
# ...

# %%
# removing unnecessary column (index_col=0) and changing ND values to NaN (na_values='ND')
df = pd.read_csv('dataset/Foreign_Exchange_Rates.csv', index_col=0, na_values='ND')
df
# Out:
#       Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0     2000-01-03                             1.5172                0.9847
# 1     2000-01-04                             1.5239                0.9700
# 2     2000-01-05                             1.5267                0.9676
# 3     2000-01-06                             1.5291                0.9686
# 4     2000-01-07                             1.5272                0.9714
# ...          ...                                ...                   ...
# 5212  2019-12-25                                NaN                   NaN
# 5213  2019-12-26                             1.4411                0.9007
# 5214  2019-12-27                             1.4331                0.8949
# 5215  2019-12-30                             1.4278                0.8915
# 5216  2019-12-31                             1.4225                0.8907
#
#       NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# ...

# %%
# peeking through the first ten rows of the dataset (default is 5)
df.head(10)
# Out:
#    Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0  2000-01-03                             1.5172                0.9847
# 1  2000-01-04                             1.5239                0.9700
# 2  2000-01-05                             1.5267                0.9676
# 3  2000-01-06                             1.5291                0.9686
# 4  2000-01-07                             1.5272                0.9714
# 5  2000-01-10                             1.5242                0.9754
# 6  2000-01-11                             1.5209                0.9688
# 7  2000-01-12                             1.5202                0.9727
# 8  2000-01-13                             1.4954                0.9737
# 9  2000-01-14                             1.5004                0.9874
#
#    NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                               1.9033
# 1                               1.9238
# 2                               1.9339
# ...

# %%
# Checking to see the sum of null(empty) values in our dataset....
df.isnull().sum()
# Out:
# Time Serie                                     0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            198
# EURO AREA - EURO/US$                         198
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          198
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    198
# BRAZIL - REAL/US$                            198
# CANADA - CANADIAN DOLLAR/US$                 198
# CHINA - YUAN/US$                             197
# HONG KONG - HONG KONG DOLLAR/US$             198
# INDIA - INDIAN RUPEE/US$                     199
# KOREA - WON/US$                              198
# MEXICO - MEXICAN PESO/US$                    198
# SOUTH AFRICA - RAND/US$                      198
# SINGAPORE - SINGAPORE DOLLAR/US$             198
# DENMARK - DANISH KRONE/US$                   198
# JAPAN - YEN/US$                              198
# MALAYSIA - RINGGIT/US$                       198
# NORWAY - NORWEGIAN KRONE/US$                 198
# SWEDEN - KRONA/US$                           198
# ...

# %%
# checking for unique values in all columns
df.nunique()
# Out:
# Time Serie                                   5217
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            2958
# EURO AREA - EURO/US$                         2703
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          2680
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    2302
# BRAZIL - REAL/US$                            3879
# CANADA - CANADIAN DOLLAR/US$                 3146
# CHINA - YUAN/US$                             2710
# HONG KONG - HONG KONG DOLLAR/US$              892
# INDIA - INDIAN RUPEE/US$                     1997
# KOREA - WON/US$                              3422
# MEXICO - MEXICAN PESO/US$                    4248
# SOUTH AFRICA - RAND/US$                      3758
# SINGAPORE - SINGAPORE DOLLAR/US$             2926
# DENMARK - DANISH KRONE/US$                   4461
# JAPAN - YEN/US$                              2847
# MALAYSIA - RINGGIT/US$                       1787
# NORWAY - NORWEGIAN KRONE/US$                 4510
# SWEDEN - KRONA/US$                           4573
# ...

# %%
# ...dropping null values in our dataset.
df.dropna()
# Out:
#       Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0     2000-01-03                             1.5172                0.9847
# 1     2000-01-04                             1.5239                0.9700
# 2     2000-01-05                             1.5267                0.9676
# 3     2000-01-06                             1.5291                0.9686
# 4     2000-01-07                             1.5272                0.9714
# ...          ...                                ...                   ...
# 5211  2019-12-24                             1.4445                0.9022
# 5213  2019-12-26                             1.4411                0.9007
# 5214  2019-12-27                             1.4331                0.8949
# 5215  2019-12-30                             1.4278                0.8915
# 5216  2019-12-31                             1.4225                0.8907
#
#       NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# ...

# %%
# About our dataset (rows and columns)
shape = df.shape
print("There are {} rows and {} columns in our Foreign Exchange dataset".format(shape[0],shape[1]))
columns = df.columns
print("Columns\n",columns)
info = df.info
print("Information of our Foreign Exchange Dataset\n",info)
# Out:
# There are 5217 rows and 23 columns in our Foreign Exchange dataset
# Columns
#  Index(['Time Serie', 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
#        'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
#        'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$',
#        'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$',
#        'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$',
#        'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$',
#        'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$',
#        'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$',
#        'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$',
#        'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$',
#        'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$',
#        'THAILAND - BAHT/US$'],
#       dtype='object')
# Information of our Foreign Exchange Dataset
# ...

# %%
new_df = df[['Time Serie','UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'SOUTH AFRICA - RAND/US$', 'INDIA - INDIAN RUPEE/US$']]
new_df.head(10)
# Out:
#    Time Serie  UNITED KINGDOM - UNITED KINGDOM POUND/US$  \
# 0  2000-01-03                                     0.6146
# 1  2000-01-04                                     0.6109
# 2  2000-01-05                                     0.6092
# 3  2000-01-06                                     0.6070
# 4  2000-01-07                                     0.6104
# 5  2000-01-10                                     0.6107
# 6  2000-01-11                                     0.6068
# 7  2000-01-12                                     0.6073
# 8  2000-01-13                                     0.6067
# 9  2000-01-14                                     0.6115
#
#    SOUTH AFRICA - RAND/US$  INDIA - INDIAN RUPEE/US$
# 0                   6.1260                     43.55
# 1                   6.0850                     43.55
# 2                   6.0700                     43.55
# 3                   6.0800                     43.55
# 4                   6.0570                     43.55
# ...

# %%
# renaming our new dataset using default country curency
new_df2 = new_df.rename(columns = 
              {'UNITED KINGDOM - UNITED KINGDOM POUND/US$' : 'GBP',
               'SOUTH AFRICA - RAND/US$': 'ZAR',
               'INDIA - INDIAN RUPEE/US$': 'INR'})
new_df2
# Out:
#       Time Serie     GBP     ZAR    INR
# 0     2000-01-03  0.6146   6.126  43.55
# 1     2000-01-04  0.6109   6.085  43.55
# 2     2000-01-05  0.6092   6.070  43.55
# 3     2000-01-06  0.6070   6.080  43.55
# 4     2000-01-07  0.6104   6.057  43.55
# ...          ...     ...     ...    ...
# 5212  2019-12-25     NaN     NaN    NaN
# 5213  2019-12-26  0.7688  14.132  71.28
# 5214  2019-12-27  0.7639  14.025  71.45
# 5215  2019-12-30  0.7610  14.056  71.30
# 5216  2019-12-31  0.7536  13.973  71.36
#
# [5217 rows x 4 columns]

# %%
# Describing our new dataframe.
new_df.describe()
# Out:
#        UNITED KINGDOM - UNITED KINGDOM POUND/US$  SOUTH AFRICA - RAND/US$  \
# count                                5019.000000              5019.000000
# mean                                    0.640372                 9.420283
# std                                     0.082611                 2.831181
# min                                     0.473800                 5.615000
# 25%                                     0.587400                 7.112250
# 50%                                     0.636400                 8.165800
# 75%                                     0.692350                11.624500
# max                                     0.828700                16.884500
#
#        INDIA - INDIAN RUPEE/US$
# count               5018.000000
# mean                  52.718519
# std                    9.680986
# min                   38.480000
# 25%                   45.250000
# 50%                   48.090000
# 75%                   62.432500
# max                   74.330000

# %%
new_df2
# Out:
#       Time Serie     GBP     ZAR    INR
# 0     2000-01-03  0.6146   6.126  43.55
# 1     2000-01-04  0.6109   6.085  43.55
# 2     2000-01-05  0.6092   6.070  43.55
# 3     2000-01-06  0.6070   6.080  43.55
# 4     2000-01-07  0.6104   6.057  43.55
# ...          ...     ...     ...    ...
# 5212  2019-12-25     NaN     NaN    NaN
# 5213  2019-12-26  0.7688  14.132  71.28
# 5214  2019-12-27  0.7639  14.025  71.45
# 5215  2019-12-30  0.7610  14.056  71.30
# 5216  2019-12-31  0.7536  13.973  71.36
#
# [5217 rows x 4 columns]

# %%
''' # Time series and 
plt.plot(new_df2['Time Serie'], new_df2.GBP, label='GBP')
plt.plot(new_df2['Time Serie'], new_df2.ZAR, label='ZAR')
plt.plot(new_df2['Time Serie'], new_df2.INR, label='INR')
plt.xlabel('Date')
plt.ylabel('Currency')
plt.grid(True)'''
# Out:
# " # Time series and \nplt.plot(new_df2['Time Serie'], new_df2.GBP, label='GBP')\nplt.plot(new_df2['Time Serie'], new_df2.ZAR, label='ZAR')\nplt.plot(new_df2['Time Serie'], new_df2.INR, label='INR')\nplt.xlabel('Date')\nplt.ylabel('Currency')\nplt.grid(True)"

# %%
# Plotting data for three coulumns
plt.plot(new_df2['GBP'])

# %%
plt.plot(new_df2['ZAR'])

# %%
plt.plot(new_df2['INR'])

# %%
# minimun value in INDIA
new_df2['INR'].max()
# Out:
# 74.33

# %%
# maximum value in SOUTH AFRICA
new_df2['ZAR'].max()
# Out:
# 16.8845

# %%
# the mean value
new_df2.mean()
# Out:
# C:\Users\Mary Solomon\AppData\Local\Temp\ipykernel_14484\3567549756.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df2.mean()
# GBP     0.640372
# ZAR     9.420283
# INR    52.718519
# dtype: float64

# %%
# the standard deviation
new_df2.std()
# Out:
# C:\Users\Mary Solomon\AppData\Local\Temp\ipykernel_14484\3905140697.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df2.std()
# GBP    0.082611
# ZAR    2.831181
# INR    9.680986
# dtype: float64
