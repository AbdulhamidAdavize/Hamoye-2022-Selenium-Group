# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah2020/Hamoye-2022-Selenium-Group/blob/Abdullahi_Isa_Ahmed/Abdullahi_Isa_Ahmed_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Foreign Exchange Rates 2000-2019**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure, show
import seaborn as sns; sns.set()

import plotly.graph_objects as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


print('Setup Completed!')
# Out:
# Setup Completed!

# %%
#import our dataset

forex_df = pd.read_csv("/content/Foreign_Exchange_Rates.csv" )

# %% [markdown]
# **Let know our dataset**

# %%
forex_df.head()
# Out:
#    Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0           0  2000-01-03                            1.5172
# 1           1  2000-01-04                            1.5239
# 2           2  2000-01-05                            1.5267
# 3           3  2000-01-06                            1.5291
# 4           4  2000-01-07                            1.5272
#
#   EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0               0.9847                              1.9033
# 1                 0.97                              1.9238
# 2               0.9676                              1.9339
# 3               0.9686                              1.9436
# 4               0.9714                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# ...

# %%
forex_df.tail()
# Out:
#       Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 5212        5212  2019-12-25                                ND
# 5213        5213  2019-12-26                            1.4411
# 5214        5214  2019-12-27                            1.4331
# 5215        5215  2019-12-30                            1.4278
# 5216        5216  2019-12-31                            1.4225
#
#      EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 5212                   ND                                  ND
# 5213               0.9007                              1.5002
# 5214               0.8949                              1.4919
# 5215               0.8915                              1.4846
# 5216               0.8907                              1.4826
#
#      UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 5212                                        ND                ND
# 5213                                    0.7688            4.0602
# ...

# %%
print("There are {} rows and {} columns in the dataset.".format(forex_df.shape[0], forex_df.shape[1]))
# Out:
# There are 5217 rows and 24 columns in the dataset.

# %%
forex_df.dtypes
# Out:
# Unnamed: 0                                    int64
# Time Serie                                   object
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            object
# EURO AREA - EURO/US$                         object
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          object
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    object
# BRAZIL - REAL/US$                            object
# CANADA - CANADIAN DOLLAR/US$                 object
# CHINA - YUAN/US$                             object
# HONG KONG - HONG KONG DOLLAR/US$             object
# INDIA - INDIAN RUPEE/US$                     object
# KOREA - WON/US$                              object
# MEXICO - MEXICAN PESO/US$                    object
# SOUTH AFRICA - RAND/US$                      object
# SINGAPORE - SINGAPORE DOLLAR/US$             object
# DENMARK - DANISH KRONE/US$                   object
# JAPAN - YEN/US$                              object
# MALAYSIA - RINGGIT/US$                       object
# ...

# %%
#Dispay the number of unique values in each column

print("The number of unique values in each column:")
forex_df.nunique()
# Out:
# The number of unique values in each column:
# Unnamed: 0                                   5217
# Time Serie                                   5217
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            2959
# EURO AREA - EURO/US$                         2704
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          2681
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    2303
# BRAZIL - REAL/US$                            3880
# CANADA - CANADIAN DOLLAR/US$                 3147
# CHINA - YUAN/US$                             2711
# HONG KONG - HONG KONG DOLLAR/US$              893
# INDIA - INDIAN RUPEE/US$                     1998
# KOREA - WON/US$                              3423
# MEXICO - MEXICAN PESO/US$                    4249
# SOUTH AFRICA - RAND/US$                      3759
# SINGAPORE - SINGAPORE DOLLAR/US$             2927
# DENMARK - DANISH KRONE/US$                   4462
# JAPAN - YEN/US$                              2848
# MALAYSIA - RINGGIT/US$                       1788
# ...

# %%
forex_df.columns
# Out:
# Index(['Unnamed: 0', 'Time Serie', 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
#        'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
#        'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$',
#        'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$',
#        'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$',
#        'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$',
#        'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$',
#        'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$',
#        'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$',
#        'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$',
#        'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$',
#        'THAILAND - BAHT/US$'],
#       dtype='object')

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# Check for missing values and their individual percentage

# %%
missing_values = pd.DataFrame({'Count':forex_df.isna().sum(),'Percentage':forex_df.isna().sum()/len(forex_df)*100})
missing_values
# Out:
#                                            Count  Percentage
# Unnamed: 0                                     0         0.0
# Time Serie                                     0         0.0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$              0         0.0
# EURO AREA - EURO/US$                           0         0.0
# NEW ZEALAND - NEW ZELAND DOLLAR/US$            0         0.0
# UNITED KINGDOM - UNITED KINGDOM POUND/US$      0         0.0
# BRAZIL - REAL/US$                              0         0.0
# CANADA - CANADIAN DOLLAR/US$                   0         0.0
# CHINA - YUAN/US$                               0         0.0
# HONG KONG - HONG KONG DOLLAR/US$               0         0.0
# INDIA - INDIAN RUPEE/US$                       0         0.0
# KOREA - WON/US$                                0         0.0
# MEXICO - MEXICAN PESO/US$                      0         0.0
# SOUTH AFRICA - RAND/US$                        0         0.0
# ...

# %% [markdown]
# **Note:**
# *   The above dataframe clearly indicated that our dataset has no missing values.
# *   Secondly, the dataset seems to have duplicate index values. Thus, we drop Unnamed: 0 columns

# %%
forex_df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
forex_df
# Out:
#       Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0     2000-01-03                            1.5172               0.9847
# 1     2000-01-04                            1.5239                 0.97
# 2     2000-01-05                            1.5267               0.9676
# 3     2000-01-06                            1.5291               0.9686
# 4     2000-01-07                            1.5272               0.9714
# ...          ...                               ...                  ...
# 5212  2019-12-25                                ND                   ND
# 5213  2019-12-26                            1.4411               0.9007
# 5214  2019-12-27                            1.4331               0.8949
# 5215  2019-12-30                            1.4278               0.8915
# 5216  2019-12-31                            1.4225               0.8907
#
#      NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                                 1.9033
# ...

# %% [markdown]
# As seen previously, the dataframe contains object (string) data types, which ideally shouldn't be. Thus, we convert 'Time Series' column to Datetime while others to float.

# %% [markdown]
# **Convert data type**

# %%
#convert other columns to float but Time Serie (index 0)

float_list = list(forex_df)
forex_df[float_list[1:]] = forex_df[float_list[1:]].apply(pd.to_numeric, errors='coerce')

# %%
#Convert Time Serie to datetime
forex_df["Time Serie"] = pd.to_datetime(forex_df["Time Serie"])

# %%
#check datatype

forex_df.dtypes
# Out:
# Time Serie                                   datetime64[ns]
# AUSTRALIA - AUSTRALIAN DOLLAR/US$                   float64
# EURO AREA - EURO/US$                                float64
# NEW ZEALAND - NEW ZELAND DOLLAR/US$                 float64
# UNITED KINGDOM - UNITED KINGDOM POUND/US$           float64
# BRAZIL - REAL/US$                                   float64
# CANADA - CANADIAN DOLLAR/US$                        float64
# CHINA - YUAN/US$                                    float64
# HONG KONG - HONG KONG DOLLAR/US$                    float64
# INDIA - INDIAN RUPEE/US$                            float64
# KOREA - WON/US$                                     float64
# MEXICO - MEXICAN PESO/US$                           float64
# SOUTH AFRICA - RAND/US$                             float64
# SINGAPORE - SINGAPORE DOLLAR/US$                    float64
# DENMARK - DANISH KRONE/US$                          float64
# JAPAN - YEN/US$                                     float64
# ...

# %% [markdown]
# **Imputaion**

# %%
# Fill ND values with previous and next values

#Step1: replace ND with NaN 
forex_df = forex_df.replace("ND", np.nan)

#Step2: do forward and backward filling on NaN
forex_df = forex_df.bfill().ffill()

# %%
forex_df.tail()
# Out:
#      Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 5212 2019-12-25                             1.4411                0.9007
# 5213 2019-12-26                             1.4411                0.9007
# 5214 2019-12-27                             1.4331                0.8949
# 5215 2019-12-30                             1.4278                0.8915
# 5216 2019-12-31                             1.4225                0.8907
#
#       NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 5212                               1.5002
# 5213                               1.5002
# 5214                               1.4919
# 5215                               1.4846
# 5216                               1.4826
#
#       UNITED KINGDOM - UNITED KINGDOM POUND/US$  BRAZIL - REAL/US$  \
# 5212                                     0.7688             4.0602
# 5213                                     0.7688             4.0602
# ...

# %% [markdown]
# # **Visualisation**

# %% [markdown]
# Let plot all currency types

# %%
Currency_df = forex_df.melt(id_vars=["Time Serie"], 
        var_name="Currency type", 
        value_name="Value")

# %%
Currency_df
# Out:
#        Time Serie                      Currency type    Value
# 0      2000-01-03  AUSTRALIA - AUSTRALIAN DOLLAR/US$   1.5172
# 1      2000-01-04  AUSTRALIA - AUSTRALIAN DOLLAR/US$   1.5239
# 2      2000-01-05  AUSTRALIA - AUSTRALIAN DOLLAR/US$   1.5267
# 3      2000-01-06  AUSTRALIA - AUSTRALIAN DOLLAR/US$   1.5291
# 4      2000-01-07  AUSTRALIA - AUSTRALIAN DOLLAR/US$   1.5272
# ...           ...                                ...      ...
# 114769 2019-12-25                THAILAND - BAHT/US$  30.1500
# 114770 2019-12-26                THAILAND - BAHT/US$  30.1500
# 114771 2019-12-27                THAILAND - BAHT/US$  30.1400
# 114772 2019-12-30                THAILAND - BAHT/US$  29.9400
# 114773 2019-12-31                THAILAND - BAHT/US$  29.7500
#
# [114774 rows x 3 columns]

# %%
#plot 

sns.set_style("white")
plt.figure(figsize=(20,10))
sns.lineplot(x="Time Serie", y="Value", hue="Currency type",palette='deep',data=Currency_df)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# Let's take a look at how the exchange rate fluctuated for the three targetted currencies: **UNITED KINGDOM, SOUTH AFRICA** , and **INDIA**

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=forex_df['Time Serie'],
                y=forex_df['UNITED KINGDOM - UNITED KINGDOM POUND/US$'],
                name="POUND/US$",
                line_color='red'))

fig.add_trace(go.Scatter(
                x=forex_df['Time Serie'],
                y=forex_df['SOUTH AFRICA - RAND/US$'],
                name="RAND/US$",
                line_color='blue'))


fig.add_trace(go.Scatter(
                x=forex_df['Time Serie'],
                y=forex_df['INDIA - INDIAN RUPEE/US$'],
                name="INR/USD",
                line_color='orange'))


fig.update_layout(title_text="Foreign Exchange Rates (2000 - 2019)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# select two columns
new_forecast_df = forex_df[['Time Serie', 'INDIA - INDIAN RUPEE/US$']]

# %%
new_forecast_df
# Out:
#      Time Serie  INDIA - INDIAN RUPEE/US$
# 0    2000-01-03                     43.55
# 1    2000-01-04                     43.55
# 2    2000-01-05                     43.55
# 3    2000-01-06                     43.55
# 4    2000-01-07                     43.55
# ...         ...                       ...
# 5212 2019-12-25                     71.28
# 5213 2019-12-26                     71.28
# 5214 2019-12-27                     71.45
# 5215 2019-12-30                     71.30
# 5216 2019-12-31                     71.36
#
# [5217 rows x 2 columns]

# %%
#Let rename our columns

new_forecast_df.columns = ["Year", "INDIAN RUPEE/US$"]
new_forecast_df
# Out:
#            Year  INDIAN RUPEE/US$
# 0    2000-01-03             43.55
# 1    2000-01-04             43.55
# 2    2000-01-05             43.55
# 3    2000-01-06             43.55
# 4    2000-01-07             43.55
# ...         ...               ...
# 5212 2019-12-25             71.28
# 5213 2019-12-26             71.28
# 5214 2019-12-27             71.45
# 5215 2019-12-30             71.30
# 5216 2019-12-31             71.36
#
# [5217 rows x 2 columns]

# %%
#Let remove index column

new_forecast_df.set_index("Year", inplace = True)

# %%
new_forecast_df
# Out:
#             INDIAN RUPEE/US$
# Year
# 2000-01-03             43.55
# 2000-01-04             43.55
# 2000-01-05             43.55
# 2000-01-06             43.55
# 2000-01-07             43.55
# ...                      ...
# 2019-12-25             71.28
# 2019-12-26             71.28
# 2019-12-27             71.45
# 2019-12-30             71.30
# 2019-12-31             71.36
#
# [5217 rows x 1 columns]

# %%
new_forecast_df.dtypes
# Out:
# INDIAN RUPEE/US$    float64
# dtype: object

# %%
new_forecast_df.describe()
# Out:
#        INDIAN RUPEE/US$
# count       5217.000000
# mean          52.764420
# std            9.697379
# min           38.480000
# 25%           45.270000
# 50%           48.110000
# 75%           62.470000
# max           74.330000

# %% [markdown]
# Visualize the new data

# %%
new_forecast_df.plot()

# %% [markdown]
# # **ARIMA and Seasonal ARIMA**

# %%
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller
print("Setup Completed!")
# Out:
# Setup Completed!
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
test_result = adfuller(new_forecast_df['INDIAN RUPEE/US$'])

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(Rate):
    result=adfuller(Rate)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(new_forecast_df['INDIAN RUPEE/US$'])
# Out:
# ADF Test Statistic : -0.09395440665349426
# p-value : 0.9500373786077675
# #Lags Used : 28
# Number of Observations Used : 5188
# Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# **Note:**
#
# The model above have indicated to be a non-stationary

# %% [markdown]
# # **Differencing**

# %%
new_forecast_df['Indian Rufee First Difference'] = new_forecast_df['INDIAN RUPEE/US$'] - new_forecast_df['INDIAN RUPEE/US$'].shift(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_forecast_df['INDIAN RUPEE/US$'].shift(1)
# Out:
# Year
# 2000-01-03      NaN
# 2000-01-04    43.55
# 2000-01-05    43.55
# 2000-01-06    43.55
# 2000-01-07    43.55
#               ...
# 2019-12-25    71.23
# 2019-12-26    71.28
# 2019-12-27    71.28
# 2019-12-30    71.45
# 2019-12-31    71.30
# Name: INDIAN RUPEE/US$, Length: 5217, dtype: float64

# %%
new_forecast_df['Seasonal First Difference'] = new_forecast_df['INDIAN RUPEE/US$'] - new_forecast_df['INDIAN RUPEE/US$'].shift(120)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_forecast_df
# Out:
#             INDIAN RUPEE/US$  Indian Rufee First Difference  \
# Year
# 2000-01-03             43.55                            NaN
# 2000-01-04             43.55                           0.00
# 2000-01-05             43.55                           0.00
# 2000-01-06             43.55                           0.00
# 2000-01-07             43.55                           0.00
# ...                      ...                            ...
# 2019-12-25             71.28                           0.05
# 2019-12-26             71.28                           0.00
# 2019-12-27             71.45                           0.17
# 2019-12-30             71.30                          -0.15
# 2019-12-31             71.36                           0.06
#
#             Seasonal First Difference
# Year
# 2000-01-03                        NaN
# 2000-01-04                        NaN
# 2000-01-05                        NaN
# 2000-01-06                        NaN
# ...

# %%
## Again test dickey fuller test

adfuller_test(new_forecast_df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -4.60790884768039
# p-value : 0.000124902729713054
# #Lags Used : 26
# Number of Observations Used : 5070
# Strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
new_forecast_df['Seasonal First Difference'].plot()

# %% [markdown]
# # **Auto Regressive Model**
